# %%
# Out:
# 0

# %%
def find_index_post(id):
    for i, p in enumerate(data):
        if p['id'] == id:
            return i

# %%
# kuch = int(input("Enter the id to find index: "))
print(data['id'] == 1)
# Out:
# True
