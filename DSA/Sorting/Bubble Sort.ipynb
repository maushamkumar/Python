# %% [markdown]
# ## Bubble Sort

# %% [markdown]
# In term
#
# From a array select the minimum and swap this. This is all selection about.
#
# arr = [5, 4, 2, 3]
#
# In this array min is 2
#
# First step **Swap Happend between 0 and min(arr)**
#
# Now the array will become like
#
# arr = [2, 4, 5, 3]
#
# Second step
#
# Will start from 1 and find the min that is 3
#
# Swap it 1 & min(arr)
#
#
# **Simple Explaintion**
# First step swap happen between 0 and min
#
# Second step swap happen between 1 and min after first index
#
# Third step swap happen between 2 and min after second index
#
# we just have perfor 3 time swaping for len of 4 arr.
#
# This is all about Bubble sort.

# %%
arr = [9, 46, 24, 52, 20, 13]

n = len(arr)
for i in range(n-2):
    min = i
    for j in range(i, n-1):
        if arr[j] < arr[min]:
            min = j
    arr[i], arr[min] = arr[min], arr[i]
    
print(arr)
# Out:
# [9, 20, 24, 46, 52, 13]

# %%
arr = [9, 46, 24, 52, 20, 13]

n = len(arr)
for i in range(n - 1):
    min_index = i
    for j in range(i + 1, n):
        if arr[j] < arr[min_index]:
            min_index = j
    arr[i], arr[min_index] = arr[min_index], arr[i]

print(arr)
# Out:
# [9, 13, 20, 24, 46, 52]

# %% [markdown]
# ## Selection Sort

# %%
arr = [9, 46, 24, 52, 20, 13]

n = len(arr)

for i in range(n):
    is_swap = 0
    for j in range(n-i-1):
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]
            is_swap = 1
            
    if is_swap == 0:
        break
            
        
    # print('-'*20)

print(arr)
# Out:
# [9, 13, 20, 24, 46, 52]

# %% [markdown]
# ## Insertion sort

# %%
arr = [14, 9, 15, 12, 6, 8, 13]
for i in range(len(arr)):
    
    for j in range(i-1, -1, -1):
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]
        else:
            break
        
print(arr)
# Out:
# [6, 8, 9, 12, 13, 14, 15]

# %%
arr = [14, 9, 15, 12, 6, 8, 13]
for i in range(len(arr)):
    for j in range(i-1, -1, -1):
        print(j)
    if i == 3: 
        break
# Out:
# 0
# 1
# 0
# 2
# 1
# 0
