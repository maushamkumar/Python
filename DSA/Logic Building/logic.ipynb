# %%
strs = ["flower","flow","flight"]

def Solution(strs):
    if not str: 
        return ""
    
    prefix = strs[0]
    for word in strs[1:]:
        while not word.startswith(prefix):
            prefix = prefix[:-1]
            if prefix == "":
                return ""
            
    return prefix

Solution(strs)
# Out:
# 'fl'

# %%
strs = ["flower","flow","flight"]
def Solution(v):
    ans = ""
    v = sorted(v)
    first = v[0] 
    last = v[-1]
    
    for i in range(min(len(first), len(last))):
        if (first[i] != last[i]):
            return ans
        ans += first[i]
    return ans

Solution(strs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 15
#       8     return min(len(first))
#       9     # for i in range(min(len(first), len(last))):
#      10     #     if (first[i] != last[i]):
#      11     #         return ans
#      12     #     ans += first[i]
#      13     # return ans
# ---> 15 Solution(strs)
#
# Cell In[7], line 8, in Solution(v)
#       5 first = v[0]
#       6 last = v[-1]
# ----> 8 return min(len(first))
#
# TypeError: 'int' object is not iterable

# %%
nums = [0,0,1,1,1,2,2,3,3,4]
num = []
for i in nums:
    if i not in num:
        num.append(i)
        
print(num)
# Out:
# [0, 1, 2, 3, 4]

# %%
def Solution(nums):
    return len(set(nums))

Solution(nums)
# Out:
# 5

# %%
def removeDuplicates(nums):
    if not nums:
        return 0

    k = 1  # position of next unique element

    for i in range(1, len(nums)):
        if nums[i] != nums[i - 1]:
            nums[k] = nums[i]
            k += 1

    return k

nums = [0,0,1,1,1,2,2,3,3,4]
removeDuplicates(nums)
# Out:
# 5

# %%
nums = [1,3,5,6]
target = 5

# nums = [1,3,5,6]
# target = 2

nums = [1,3,5,6]
print(len(nums))
target = 7

index = 0 
for i in range(len(nums)):
    if nums[i] >= target:
        index = i 
        break
index = len(num) - 1
print(index)
# Out:
# 4
# 4

# %%
nums = [1,3,5,6]
target = 2
index = 0 
for i in range(len(nums)):
    if nums[i] >= target:
        index = i 
print(index)
# Out:
# 3

# %%
nums = [1,3,5,6,7]
target = 2

left = 0 
right = len(nums) - 1 

while left <= right:
    
    mid = (left + right) //2 
    
    if nums[mid] == target:
        print(mid)
    
    elif nums[mid] > target: 
        right = mid - 1
        
    else: 
        left = mid + 1 

print(mid)
# Out:
# 1

# %%
digits = [1,2,3]
carry = 1 
for i in range(len(digits)-1, -1, -1):
    s = digits[i] + carry
    digits[i] = s % 10
    carry = s // 10
if carry: 
    digits = [1] + digits
print(digits)
# Out:
# [1, 0]

# %%
nums = [2,7,11,15] 
target = 9

for i in range(1, len(nums)):
    if (target - nums[i]) == nums[i -1]:
        print(i-1, i)
# Out:
# 0 1

# %%
nums = [-10,-3,0,5,9]

left = 0 
right = len(nums) - 1 
while left

# %%
right
# Out:
# 4

# %%
# If any value appear twice in array return ture. 
nums = [3,3]
seen = {}
for i, val in enumerate(nums):
    if val in seen:
        print(True)
        break
    seen[val] = True
else: 
    print("False")
print(seen)
# Out:
# True
# {3: True}

# %%
# nums = [1,2,3,1]
# k = 3

nums = [1,0,1,1]
k = 1
for i in range(len(nums)): 
    for j in range(1, len(nums)):
        if nums[i] == nums[j] and abs(i - j) == k: 
            print(True)
else:
    print(False)
# Out:
# True
# True
# False

# %%
nums = [1,0,1,1]
k = 1
for i in range(len(nums)): 
    for j in range(1, len(nums)):
        if nums[i] == nums[j] and abs(i - j) <= k: 
            print(True)
        break
# Out:
# True

# %%
nums = [1,0,1,1]
k = 1

last_seen = {}
for i in range(len(nums)): 
    val = nums[i]
    
    if val in last_seen: 
        if abs(i - last_seen[val]) <= k: 
            print(True)
            exit()
            
    last_seen[val] = i 
print(False)
# Out:
# True
# False
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
prices = [7,6,4,3,1]

highest = 0 
buy = prices[0]

for i in range(1, len(prices)): 
    if prices[i] > buy:
        profit = prices[i] - buy
        
        if profit > highest: 
            highest = profit
        
    
    else: 
        buy = prices[i]
        

# print(buy)
print(highest)
# Out:
# 0

# %%
nums = [4,1,2,1,2]

seen = {}

for i in nums: 
    if i in seen: 
        seen[i] += 1 
    else: 
        seen[i] = 1

# %%
for i, val in enumerate(seen):
    print(val)
# Out:
# 4
# 1
# 2

# %%
seen
# Out:
# {4: 1, 1: 2, 2: 2}

# %%
for k in seen:
    print(k)
# Out:
# 4
# 1
# 2

# %%
for k in seen.values():
    if k == 1: 
        print(seen[k])
# Out:
# 2

# %%
for key, value in seen.items():
    if value == 1:
        print(key)
# Out:
# 4

# %%
class Solution(object):
    def singleNumber(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        
        seen = {}
        
        for i in nums: 
            if i in seen: 
                seen[i] += 1 
            else: 
                seen[i] = 1 
                
        for key, value in seen.items():
            if value == 1: 
                return key

# %%
class Solution(object):
    def singleNumber(self, nums):
        result = 0
        for n in nums:
            result ^= n
        return result

# %%
s = Solution()

# %%
s.singleNumber(nums)
# Out:
# 4
