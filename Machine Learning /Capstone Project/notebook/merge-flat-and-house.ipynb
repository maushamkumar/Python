# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0                1 BHK Flat in Sector 71 Gurgaon          flat
# 1       2 Bedroom House for sale in Laxman Vihar         house
# 2   4 Bedroom House for sale in Sector 1 Gurgaon         house
# 3                2 BHK Flat in Sector 81 Gurgaon          flat
# 4  4 Bedroom House for sale in Sector 28 Gurgaon         house
#
#                     society  price  price_per_sqft    area  \
# 0  signature andour heights   0.39          9846.0   396.0
# 1               independent   0.55          6813.0   807.0
# 2               independent   1.85         16003.0  1156.0
# 3  signature global city 81   0.82          8639.0   949.0
# 4      suncity essel towers   6.00         22222.0  2700.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0               Super Built up area 325(30.19 sq.m.)        1         1
# 1                                  Built Up area: 75        2         1
# 2                    Carpet area: 1156 (107.4 sq.m.)        4         3
# 3  Built Up area: 955 (88.72 sq.m.)Carpet area: 5...        2         2
# 4                        Plot area 300(250.84 sq.m.)        4         4
#
#   balcony additionalRoom                                            address  \
# 0       2  not available                Sector 71 Gurgaon, Gurgaon, Haryana
# 1       1  not available                     Laxman Vihar, Gurgaon, Haryana
# 2       2  not available  975 Friends Colony, Sector 1 Gurgaon, Gurgaon,...
# 3       3  not available     Sector 81, Sector 81 Gurgaon, Gurgaon, Haryana
# 4      3+     study room                Sector 28 Gurgaon, Gurgaon, Haryana
#
#    floorNum facing     agePossession  \
# 0       1.0    NaN   0 to 1 Year Old
# 1       1.0    NaN  5 to 10 Year Old
# 2       3.0    NaN         undefined
# 3       2.0   East         undefined
# 4       3.0   East      10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Bigbasket SPR 5K DS', 'iON Digital Zone, DPG...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2                                                NaN
# 3  ['Orris Community Center', 'HP Petrol Pump', '...
# 4  ['Iffco chowk metro station', 'Mg road metro s...
#
#                                          description  \
# 0  Signature andour heights is one of the most po...
# 1  We are proud owners of house/villa available f...
# 2  4bhk residential house for resale in sector 1 ...
# 3  Best in class property available at sector 81 ...
# 4  5bhk spacious independent villa for sale in co...
#
#                                       furnishDetails  \
# 0                                                 []
# 1  ['3 Fan', '1 Exhaust Fan', '6 Light', 'No AC',...
# 2  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 4  ['5 Wardrobe', '10 Fan', '10 Light', '1 Modula...
#
#                                             features  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating
# 0  ['Management4 out of 5', 'Green Area5 out of 5...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2                                                NaN
# 3  ['Environment4.5 out of 5', 'Lifestyle4 out of...
# 4  ['Environment4 out of 5', 'Lifestyle5 out of 5...

# %%
df.shape
# Out:
# (3960, 20)

# %%
df.to_csv('gurgaon_properties.csv',index=False)
